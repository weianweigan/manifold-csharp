# %% [markdown]
# # Revlove 🔄
#
# > Revolve generates a solid by rotating a profile shape around an axis by 360 degrees.

# %%
#r "nuget: ManifoldNET.Notebooks, *-*"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>ManifoldNET.Notebooks, 1.0.4-alpha</span></li></ul></div></div>

# %%
using ManifoldNET;
using static ManifoldNET.Manifold;

# %% [markdown]
# # Sphere⚪
#
# First, we cloud generate a sphere by rotate a circle.

# %%
var section = CrossSection.Circle(1f, 100);
Manifold.Revolve(section.Polygons(), 100)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <script type="module" src="https://ajax.googleapis.com/ajax/libs/model-viewer/3.5.0/model-viewer.min.js"></script>
#     <script src="https://cdn.jsdelivr.net/npm/js-base64@3.6.1/base64.min.js"></script>
#     <style>
#         html, body {
#             height: 100%;
#             margin: 0;
#             padding: 0;
#         }
#
#         model-viewer {
#             width: 100%;
#             height: 500px;
#         }
#     </style>
# </head>
# <body>
#     <model-viewer id="modelViewer"
#         autoplay
#         alt="3D Model"
#         shadow-intensity="1" camera-controls
#         touch-action="pan-y" src="......"></model-viewer>
# </body>
# </html>

# %% [markdown]
# # Loop🔄
#
# When a translation apply to circle, we can generate a loop by rotate circle.

# %%
var section = CrossSection
    .Circle(1f, 100)
    .Translate(10,10);
Manifold.Revolve(section.Polygons(), 100)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <script type="module" src="https://ajax.googleapis.com/ajax/libs/model-viewer/3.5.0/model-viewer.min.js"></script>
#     <script src="https://cdn.jsdelivr.net/npm/js-base64@3.6.1/base64.min.js"></script>
#     <style>
#         html, body {
#             height: 100%;
#             margin: 0;
#             padding: 0;
#         }
#
#         model-viewer {
#             width: 100%;
#             height: 500px;
#         }
#     </style>
# </head>
# <body>
#     <model-viewer id="modelViewer"
#         autoplay
#         alt="3D Model"
#         shadow-intensity="1" camera-controls
#         touch-action="pan-y" src="......"></model-viewer>
# </body>
# </html>

# %% [markdown]
# # Revolve squre

# %%
var section = CrossSection
    .Square(1, 1, true)
    .Translate(10, 10);
Manifold.Revolve(section.Polygons(), 100)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <script type="module" src="https://ajax.googleapis.com/ajax/libs/model-viewer/3.5.0/model-viewer.min.js"></script>
#     <script src="https://cdn.jsdelivr.net/npm/js-base64@3.6.1/base64.min.js"></script>
#     <style>
#         html, body {
#             height: 100%;
#             margin: 0;
#             padding: 0;
#         }
#
#         model-viewer {
#             width: 100%;
#             height: 500px;
#         }
#     </style>
# </head>
# <body>
#     <model-viewer id="modelViewer"
#         autoplay
#         alt="3D Model"
#         shadow-intensity="1" camera-controls
#         touch-action="pan-y" src="......"></model-viewer>
# </body>
# </html>
